# %%
import os
from shutil import copyfile

# %%
in_dir = r"/media/ross/ssd/00_kauai_dar2015/00_raw"
out_dir = r"/media/ross/ssd/00_kauai_dar2015/01_toberenamed"

# %%
filelist = [f for f in os.listdir(in_dir)]

# %%
for fi in filelist:
    if '-' in fi:
        renamed_fi = fi.replace('-', '_')
        print(fi, '  >>>  ', renamed_fi)

        in_path = os.path.join(in_dir, fi)
        out_path = os.path.join(out_dir, renamed_fi)

        copyfile(in_path, out_path)
        os.remove(in_path)
# Out:
# kauai_1-2_1009.tfw   >>>   kauai_1_2_1009.tfw
# kauai_1-2_1009.tif   >>>   kauai_1_2_1009.tif
# kauai_1-2_1009.tif.aux.xml   >>>   kauai_1_2_1009.tif.aux.xml
# kauai_1-2_1009.tif.ovr   >>>   kauai_1_2_1009.tif.ovr
# kauai_1-2_1009.tif.xml   >>>   kauai_1_2_1009.tif.xml
# kauai_1-2_1010.tfw   >>>   kauai_1_2_1010.tfw
# kauai_1-2_1010.tif   >>>   kauai_1_2_1010.tif
# kauai_1-2_1010.tif.aux.xml   >>>   kauai_1_2_1010.tif.aux.xml
# kauai_1-2_1010.tif.ovr   >>>   kauai_1_2_1010.tif.ovr
# kauai_1-2_1010.tif.xml   >>>   kauai_1_2_1010.tif.xml
# kauai_1-2_1069.tfw   >>>   kauai_1_2_1069.tfw
# kauai_1-2_1069.tif   >>>   kauai_1_2_1069.tif
# kauai_1-2_1069.tif.aux.xml   >>>   kauai_1_2_1069.tif.aux.xml
# kauai_1-2_1069.tif.ovr   >>>   kauai_1_2_1069.tif.ovr
# kauai_1-2_1069.tif.xml   >>>   kauai_1_2_1069.tif.xml
# kauai_1-2_1070.tfw   >>>   kauai_1_2_1070.tfw
# kauai_1-2_2935.tif.xml   >>>   kauai_1_2_2935.tif.xml
# kauai_1-2_2936.tfw   >>>   kauai_1_2_2936.tfw
# ...
