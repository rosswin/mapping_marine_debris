# %%
import os
from shutil import copyfile

# %%
in_dir = r"/media/ross/ssd/00_kauai_dar2015/tiles/00_gto_raw"
out_dir = r"/media/ross/ssd/00_kauai_dar2015/01_raw_renamed"

# %%
filelist = [f for f in os.listdir(in_dir)]

# %%
for fi in filelist:
    if '-' in fi:
        renamed_fi = fi.replace('-', '_')
        print(fi, '  >>>  ', renamed_fi)

        in_path = os.path.join(in_dir, fi)
        #out_path = os.path.join(out_dir, renamed_fi)
        out_path = os.path.join(in_dir, renamed_fi)

        copyfile(in_path, out_path)
        os.remove(in_path)
# Out:
# kauai_1-2_1009.dbf   >>>   kauai_1_2_1009.dbf
# kauai_1-2_1009.prj   >>>   kauai_1_2_1009.prj
# kauai_1-2_1009.shp   >>>   kauai_1_2_1009.shp
# kauai_1-2_1009.shx   >>>   kauai_1_2_1009.shx
# kauai_1-2_1010.dbf   >>>   kauai_1_2_1010.dbf
# kauai_1-2_1010.prj   >>>   kauai_1_2_1010.prj
# kauai_1-2_1010.shp   >>>   kauai_1_2_1010.shp
# kauai_1-2_1010.shx   >>>   kauai_1_2_1010.shx
# kauai_1-2_1069.dbf   >>>   kauai_1_2_1069.dbf
# kauai_1-2_1069.prj   >>>   kauai_1_2_1069.prj
# kauai_1-2_1069.shp   >>>   kauai_1_2_1069.shp
# kauai_1-2_1069.shx   >>>   kauai_1_2_1069.shx
# kauai_1-2_1070.dbf   >>>   kauai_1_2_1070.dbf
# kauai_1-2_1070.prj   >>>   kauai_1_2_1070.prj
# kauai_1-2_1070.shp   >>>   kauai_1_2_1070.shp
# kauai_1-2_1070.shx   >>>   kauai_1_2_1070.shx
# kauai_1-2_1129.dbf   >>>   kauai_1_2_1129.dbf
# kauai_1-2_1190.prj   >>>   kauai_1_2_1190.prj
# kauai_1-2_1248.shp   >>>   kauai_1_2_1248.shp
# kauai_1-2_126.shx   >>>   kauai_1_2_126.shx
# ...
